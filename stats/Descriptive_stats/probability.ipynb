# %% [markdown]
# ### probability :-
# * probability is a measure of the likelihood of the event
# * EX :-
#    * roll a die {1,2,3,4,5,6}
#    * pr(6)  = no of way an event can occure / no of possible outcome
#    *  !/6
# ### probability addition or (probability 'or') :-
# * ***mutual***  exclusive events
# * the events are mutual exclusive if they cannot occure at the same time
# * EX :-
#    * rolling a die {1,2,3,4,5,6} when we roll a die possible outcome is any one of the following.to get 1 or 3 or 6
#    * pe(1 or 3 or 6) = p(1)+p(3)+p(6)
#                      = 1/6+1/6+1/6
#                      =3/6
#                      = 3
# * EX :-
#    * if i toss a coin ,what is probability of the coin landing on heads or tails ?
#    * pr(A or B) = P(A)+P(B)
#               * = 1/2+ 1/2
#                 = 1
# * ***non-mutual*** exclusive events
# * mutual events can occure at same time
# * EX :-you picking a card from a deck what is the propability of choosing a card that is queen or a heart ?
#     * p(q) = 4/52 ,p(heart) = 13/52,p(q and heart) 1/52
#     * p(a or b) = p(a)+p(b)-p(a and b)
#     * p(q or heart) = p(q)+p(heart)-p(q and heart)
#     * 4/52+13/52-1/52 = 16/52
# ### probaility multiplication rule :-
# * **independed events**  should not depended with other events
# * Ex :- rolling a die possibillity {1,2,3,4,5,6}
#     * each and every events are independent with each other
# * Ex1 :- what is the probAility of rollinf a **5** and the **4** in a dice?
#     * pr(a and b) = P(a)+p(b)
#     * pr(5 and 4) = 1/6*1/6 =1/36
#
# * **dependent**
# * EX :- lets us take 3 red balls and 2 green balls
#     * p(gr) = 3/5 # probaility to take red ball
#     * p(gr) = 2/4 # probaility to tale green balls

# %% [markdown]
# ### permutations
# * npr = n!/(n-r)! = 6!/(6-3)! = 6*5*4*3!/3! =120
# * where n = total no of elements
# * r = total to take possibel combinations
# ###  combinations
# * ncr = n!/r!(n-r)! = 6!/3!(6-3)! = 20
# * ![image.png](attachment:image.png)

# %% [markdown]
# ### p - value
# * ![image.png](attachment:image.png)

# %% [markdown]
# ### point Estimate :-
# * The value of any stas that estimate the a vlue of parameter
# * ![image.png](attachment:image.png)
#
# ###  confidence intervel
# * point estimate + or - margin error
#
#
# * EX :- on the quant test of cat xm the std is known that is 100 .A sample of 25 test takes has a mean of 520 .construct 95%  CI  about the mean ?
#   * when ever the population std is given  and n > 30 . we apply the test is Z- test
#   * point Estimate + or - margin of error
#   * alpha = 1-95= 0.05
#   * Xbar + or - Zaplha/2* std /root  of n
#   * upper bound = 520 + Z0.05/2*100/root of 25
#   * lower bound = 520 - X0.05/2*100/root of 25
#   * check in the Z-table for upper bound and lower bound
#   * mean = 520
#   * upper = 559.20
#   * lower = 480.8
#
# * EX :- on the quant of cat xm sample of 25 test taken has a mean of 520 with a std 80.construct 95% . what is CI?
# * ![image-3.png](attachment:image-3.png)
#  * n = 25 , xbar = 520 , std = 80,aplha = 0.05
#    * point Estimation + or - margin of error
#    * upper = 520 + t0.05/2*80 root of 25
#    * lower = 520 - t0.05/2*80 root of 25
#    * chek the T-table  ---> t of 0.05/2 = 2.0624
#       * upper = 520 + 2.064 *80 /5
#       * lower = 520 - 2.064 *80 /5
#    * mean = 520
#    * upper = 553.024
#    * lower =
# ### Hypo test :-
#  * Ex :- in the populatin .the avg  IQ is 100 with the std of 15 . researchers wants test a new  medication to see if there is postive or negative  effect
#    on intelligence ,or no effect  at all . a ,ssample of 30 participants who have the medication has mean of 140 did medicatio effect the intelligence?
#    * **steps**
#      * 1) define null hypo Mue = 100
#      * 2) define the alternative hypo !=100
#      * lower bound is - 1.96
#      * upper bound is 1.96
#      * 3) aplha = 0.05
#      * ![image-2.png](attachment:image-2.png)
#      * 4) Z = x bar - Mue /std/root of n to cal test stats
#      * 140 - 100/15/root of 30 = 40/15*root of 30 =14.60
#      * 14.60 > upper and lower
#      * if the Z is less then lower -1.96 or more them upper 1.96
