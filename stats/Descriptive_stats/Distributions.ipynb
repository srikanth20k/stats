# %% [markdown]
# #### Distributions
# * 1) Normal Distribution
# * 2) Standard Normal Distribution
# * 3) Z-Score
# * 4) Log Normal Distribution
# * 5) bernolis distribution
# * 6) binomial distribution
# #### 1) Normal Distribution
#
# * ![image.png](attachment:image.png)
#
# * **emperical formula** :- 68-95-99.7% rule
# * ![image-4.png](attachment:image-4.png)
# * ![image-2.png](attachment:image-2.png)
#
# * ex:- height,weight -> normal distribution
# #### 3) Standard Normal Distribution
# * ![image-5.png](attachment:image-5.png)
#
# * ![image-6.png](attachment:image-6.png)
#
# EX:-
#  dataset
#
# #### 2) Z-score
# * A z-score, also known as a standard score, measures how many standard deviations a data point is from the mean of a dataset. It allows for comparison between different datasets by standardizing scores. The formula for calculating a z-score is:
#
# z =(X−μ)/σ
# x = elements of varible
# μ = mean
# σ = std
# * it allow to known the area of the curve using the **z-tabe**
#
#
# * ![image-3.png](attachment:image-3.png)
# ​

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill']) # mean of total bill
# Out:
# np.float64(19.78594262295082)

# %%
np.median(df['total_bill']) # median of total bill
# Out:
# np.float64(17.795)

# %%
statistics.mode(df['total_bill']) # mode of total bill
# Out:
# 13.42

# %%
sns.boxplot(df['total_bill']) # boxplot of total bill
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.distplot(df['total_bill']) # distribution plot of total bill
# Out:
# C:\Users\SRIKANTH ADIPIREDDY\AppData\Local\Temp\ipykernel_32008\16414246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill']) # distribution plot of total bill
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(df['total_bill'],kde=True) # histogram of total bill
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df1=sns.load_dataset('iris') # load iris dataset

# %%
sns.histplot(df1['sepal_width'],kde=True) # histogram of sepal length
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
print(df1.sepal_width.mean()) # mean of sepal width
print(df1.sepal_width.median() )# median of sepal width
statistics.mode(df1.sepal_width) # mode of sepal width
# Out:
# 3.0573333333333337
# 3.0
# 3.0

# %%
sns.countplot(df1['species']) # countplot of species
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %%
np.percentile(df1['sepal_length'],[25,99]) # 25th percentile of total bill
# Out:
# array([5.1, 7.7])

# %% [markdown]
# ### outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import scipy.stats as stats

# %%
dataset = [11,10,12,14,12,15,14,13,15,102,12,14,17,19,107, 10,13,12,14,12,108,12,11,14,13,15,10,15,12,10,14,13,15,10]

# %%
sns.histplot(dataset)
# Out:
# <Axes: ylabel='Count'>

# %%
outliers = []
def det(data):
    threshold = 3
    mean = np.mean(data)
    std = np.std(data)
    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# %%
det(dataset)
# Out:
# [102, 107, 108]

# %% [markdown]
# ### IQR
# * sort the data
# * calcu Q1 and Q3
# * IQR(Q3-Q1)
# * find the lower fence(Q1-1.5(IQR))
# * find the high fence(Q1+1.5(IQR))

# %%
Q1,Q3 = np.percentile(dataset,[25,75])
print(Q1,Q3)
# Out:
# 12.0 15.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 3.0

# %%
# finding the lower and higher
lower_fence = Q1-(1.5*IQR)
higer_fence = Q3+(1.5*IQR)
print(lower_fence)
print(higer_fence)
# Out:
# 7.5
# 19.5
